# %%
from IPython.display import Image
Image("../input/image-house-prices-advanced-regression/image.jpeg")

# %% [markdown]
# #  Predict sales prices and practice feature engineering, RFs, and gradient boosting
#
# ## 1. Problem defition
#
#
# > Predict the value of the SalePrice variable.
#
# ## 2. Data
#
#
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
#
#
#     **Data Details:**
#
# * Here's a brief version of what you'll find in the data description file.
# * SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# * MSSubClass: The building class
# * MSZoning: The general zoning classification
# * LotFrontage: Linear feet of street connected to property
# * LotArea: Lot size in square feet
# * Street: Type of road access
# * Alley: Type of alley access
# * LotShape: General shape of property
# * LandContour: Flatness of the property
# * Utilities: Type of utilities available
# * LotConfig: Lot configuration
# * LandSlope: Slope of property
# * Neighborhood: Physical locations within Ames city limits
# * Condition1: Proximity to main road or railroad
# * Condition2: Proximity to main road or railroad (if a second is present)
# * BldgType: Type of dwelling
# * HouseStyle: Style of dwelling
# * OverallQual: Overall material and finish quality
# * OverallCond: Overall condition rating
# * YearBuilt: Original construction date
# * YearRemodAdd: Remodel date
# * RoofStyle: Type of roof
# * RoofMatl: Roof material
# * Exterior1st: Exterior covering on house
# * Exterior2nd: Exterior covering on house (if more than one material)
# * MasVnrType: Masonry veneer type
# * MasVnrArea: Masonry veneer area in square feet
# * ExterQual: Exterior material quality
# * ExterCond: Present condition of the material on the exterior
# * Foundation: Type of foundation
# * BsmtQual: Height of the basement
# * BsmtCond: General condition of the basement
# * BsmtExposure: Walkout or garden level basement walls
# * BsmtFinType1: Quality of basement finished area
# * BsmtFinSF1: Type 1 finished square feet
# * BsmtFinType2: Quality of second finished area (if present)
# * BsmtFinSF2: Type 2 finished square feet
# * BsmtUnfSF: Unfinished square feet of basement area
# * Total square feet of basement area
# * Heating: Type of heating
# * HeatingQC: Heating quality and condition
# * CentralAir: Central air conditioning
# * Electrical: Electrical system
# * 1stFlrSF: First Floor square feet
# * 2ndFlrSF: Second floor square feet
# * LowQualFinSF: Low quality finished square feet (all floors)
# * GrLivArea: Above grade (ground) living area square feet
# * BsmtFullBath: Basement full bathrooms
# * BsmtHalfBath: Basement half bathrooms
# * FullBath: Full bathrooms above grade
# * HalfBath: Half baths above grade
# * Bedroom: Number of bedrooms above basement level
# * Kitchen: Number of kitchens
# * KitchenQual: Kitchen quality
# * TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# * Functional: Home functionality rating
# * Fireplaces: Number of fireplaces
# * FireplaceQu: Fireplace quality
# * GarageType: Garage location
# * GarageYrBlt: Year garage was built
# * GarageFinish: Interior finish of the garage
# * GarageCars: Size of garage in car capacity
# * GarageArea: Size of garage in square feet
# * GarageQual: Garage quality
# * GarageCond: Garage condition
# * PavedDrive: Paved driveway
# * WoodDeckSF: Wood deck area in square feet
# * OpenPorchSF: Open porch area in square feet
# * EnclosedPorch: Enclosed porch area in square feet
# * 3SsnPorch: Three season porch area in square feet
# * ScreenPorch: Screen porch area in square feet
# * PoolArea: Pool area in square feet
# * PoolQC: Pool quality
# * Fence: Fence quality
# * MiscFeature: Miscellaneous feature not covered in other categories
# * MiscVal: $Value of miscellaneous feature
# * MoSold: Month Sold
# * YrSold: Year Sold
# * SaleType: Type of sale
# * SaleCondition: Condition of sale

# %% [markdown]
# ##  Evaluation
#
#  The evaluation metric for this competition is the RMSLE (root mean squared log error) between the actual and predicted auction prices
#
#  https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview/evaluation

# %% [markdown]
# # 1. Data

# %% [markdown]
# ## 1.1 Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import xgboost

# %%
df_train = pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')
df_train.head()

# %%
df_train.shape

# %%
df_train.dtypes

# %%
df_train.describe()

# %%
df_train.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df_train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# TotalBsmtSF   -0.015415   -0.238518     0.392075  0.260833     0.537808
# 1stFlrSF       0.010496   -0.251758     0.457181  0.299475     0.476224
# 2ndFlrSF       0.005590    0.307886     0.080177  0.050986     0.295493
# LowQualFinSF  -0.044230    0.046474     0.038469  0.004779    -0.030429
# GrLivArea      0.008273    0.074853     0.402797  0.263116     0.593007
# BsmtFullBath   0.002289    0.003491     0.100949  0.158155     0.111098
# BsmtHalfBath  -0.020155   -0.002333    -0.007234  0.048046    -0.040150
# FullBath       0.005587    0.131608     0.198769  0.126031     0.550600
# HalfBath       0.006784    0.177354     0.053532  0.014259     0.273458
# BedroomAbvGr   0.037719   -0.023438     0.263170  0.119690     0.101676
# KitchenAbvGr   0.002951    0.281721    -0.006069 -0.017784    -0.183882
# TotRmsAbvGrd   0.027239    0.040380     0.352096  0.190015     0.427452
# Fireplaces    -0.019772   -0.045569     0.266639  0.271364     0.396765
# GarageYrBlt    0.000072    0.085072     0.070250 -0.024947     0.547766
# GarageCars     0.016570   -0.040110     0.285691  0.154871     0.600671
# GarageArea     0.017634   -0.098672     0.344997  0.180403     0.562022
# WoodDeckSF    -0.029643   -0.012579     0.088521  0.171698     0.238923
# OpenPorchSF   -0.000477   -0.006100     0.151972  0.084774     0.308819
# EnclosedPorch  0.002889   -0.012037     0.010700 -0.018340    -0.113937
# 3SsnPorch     -0.046635   -0.043825     0.070029  0.020423     0.030371
# ScreenPorch    0.001330   -0.026030     0.041383  0.043160     0.064886
# PoolArea       0.057044    0.008283     0.206167  0.077672     0.065166
# MiscVal       -0.006242   -0.007683     0.003368  0.038068    -0.031406
# MoSold         0.021172   -0.013585     0.011200  0.001205     0.070815
# YrSold         0.000712   -0.021407     0.007450 -0.014261    -0.027347
# SalePrice     -0.021917   -0.084284     0.351799  0.263843     0.790982
#
#                OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id                0.012609  -0.012713     -0.021998   -0.050298   -0.005024
# MSSubClass       -0.059316   0.027850      0.040581    0.022936   -0.069836
# LotFrontage      -0.059213   0.123349      0.088866    0.193458    0.233633
# LotArea          -0.005636   0.014228      0.013788    0.104160    0.214103
# OverallQual      -0.091932   0.572323      0.550684    0.411876    0.239666
# OverallCond       1.000000  -0.375983      0.073741   -0.128101   -0.046231
# YearBuilt        -0.375983   1.000000      0.592855    0.315707    0.249503
# YearRemodAdd      0.073741   0.592855      1.000000    0.179618    0.128451
# MasVnrArea       -0.128101   0.315707      0.179618    1.000000    0.264736
# BsmtFinSF1       -0.046231   0.249503      0.128451    0.264736    1.000000
# BsmtFinSF2        0.040229  -0.049107     -0.067759   -0.072319   -0.050117
# BsmtUnfSF        -0.136841   0.149040      0.181133    0.114442   -0.495251
# TotalBsmtSF      -0.171098   0.391452      0.291066    0.363936    0.522396
# 1stFlrSF         -0.144203   0.281986      0.240379    0.344501    0.445863
# 2ndFlrSF          0.028942   0.010308      0.140024    0.174561   -0.137079
# LowQualFinSF      0.025494  -0.183784     -0.062419   -0.069071   -0.064503
# GrLivArea        -0.079686   0.199010      0.287389    0.390857    0.208171
# BsmtFullBath     -0.054942   0.187599      0.119470    0.085310    0.649212
# BsmtHalfBath      0.117821  -0.038162     -0.012337    0.026673    0.067418
# FullBath         -0.194149   0.468271      0.439046    0.276833    0.058543
# HalfBath         -0.060769   0.242656      0.183331    0.201444    0.004262
# BedroomAbvGr      0.012980  -0.070651     -0.040581    0.102821   -0.107355
# KitchenAbvGr     -0.087001  -0.174800     -0.149598   -0.037610   -0.081007
# TotRmsAbvGrd     -0.057583   0.095589      0.191740    0.280682    0.044316
# Fireplaces       -0.023820   0.147716      0.112581    0.249070    0.260011
# GarageYrBlt      -0.324297   0.825667      0.642277    0.252691    0.153484
# GarageCars       -0.185758   0.537850      0.420622    0.364204    0.224054
# GarageArea       -0.151521   0.478954      0.371600    0.373066    0.296970
# WoodDeckSF       -0.003334   0.224880      0.205726    0.159718    0.204306
# OpenPorchSF      -0.032589   0.188686      0.226298    0.125703    0.111761
# EnclosedPorch     0.070356  -0.387268     -0.193919   -0.110204   -0.102303
# 3SsnPorch         0.025504   0.031355      0.045286    0.018796    0.026451
# ScreenPorch       0.054811  -0.050364     -0.038740    0.061466    0.062021
# PoolArea         -0.001985   0.004950      0.005829    0.011723    0.140491
# MiscVal           0.068777  -0.034383     -0.010286   -0.029815    0.003571
# MoSold           -0.003511   0.012398      0.021490   -0.005965   -0.015727
# YrSold            0.043950  -0.013618      0.035743   -0.008201    0.014359
# SalePrice        -0.077856   0.522897      0.507101    0.477493    0.386420
#
#                ...  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id             ...   -0.029643    -0.000477       0.002889  -0.046635
# MSSubClass     ...   -0.012579    -0.006100      -0.012037  -0.043825
# LotFrontage    ...    0.088521     0.151972       0.010700   0.070029
# LotArea        ...    0.171698     0.084774      -0.018340   0.020423
# OverallQual    ...    0.238923     0.308819      -0.113937   0.030371
# OverallCond    ...   -0.003334    -0.032589       0.070356   0.025504
# YearBuilt      ...    0.224880     0.188686      -0.387268   0.031355
# YearRemodAdd   ...    0.205726     0.226298      -0.193919   0.045286
# MasVnrArea     ...    0.159718     0.125703      -0.110204   0.018796
# BsmtFinSF1     ...    0.204306     0.111761      -0.102303   0.026451
# BsmtFinSF2     ...    0.067898     0.003093       0.036543  -0.029993
# BsmtUnfSF      ...   -0.005316     0.129005      -0.002538   0.020764
# TotalBsmtSF    ...    0.232019     0.247264      -0.095478   0.037384
# 1stFlrSF       ...    0.235459     0.211671      -0.065292   0.056104
# 2ndFlrSF       ...    0.092165     0.208026       0.061989  -0.024358
# LowQualFinSF   ...   -0.025444     0.018251       0.061081  -0.004296
# GrLivArea      ...    0.247433     0.330224       0.009113   0.020643
# BsmtFullBath   ...    0.175315     0.067341      -0.049911  -0.000106
# BsmtHalfBath   ...    0.040161    -0.025324      -0.008555   0.035114
# FullBath       ...    0.187703     0.259977      -0.115093   0.035353
# HalfBath       ...    0.108080     0.199740      -0.095317  -0.004972
# BedroomAbvGr   ...    0.046854     0.093810       0.041570  -0.024478
# KitchenAbvGr   ...   -0.090130    -0.070091       0.037312  -0.024600
# TotRmsAbvGrd   ...    0.165984     0.234192       0.004151  -0.006683
# Fireplaces     ...    0.200019     0.169405      -0.024822   0.011257
# GarageYrBlt    ...    0.224577     0.228425      -0.297003   0.023544
# GarageCars     ...    0.226342     0.213569      -0.151434   0.035765
# GarageArea     ...    0.224666     0.241435      -0.121777   0.035087
# WoodDeckSF     ...    1.000000     0.058661      -0.125989  -0.032771
# OpenPorchSF    ...    0.058661     1.000000      -0.093079  -0.005842
# EnclosedPorch  ...   -0.125989    -0.093079       1.000000  -0.037305
# 3SsnPorch      ...   -0.032771    -0.005842      -0.037305   1.000000
# ScreenPorch    ...   -0.074181     0.074304      -0.082864  -0.031436
# PoolArea       ...    0.073378     0.060762       0.054203  -0.007992
# MiscVal        ...   -0.009551    -0.018584       0.018361   0.000354
# MoSold         ...    0.021011     0.071255      -0.028887   0.029474
# YrSold         ...    0.022270    -0.057619      -0.009916   0.018645
# SalePrice      ...    0.324413     0.315856      -0.128578   0.044584
#
#                ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# Id                0.001330  0.057044 -0.006242  0.021172  0.000712  -0.021917
# MSSubClass       -0.026030  0.008283 -0.007683 -0.013585 -0.021407  -0.084284
# LotFrontage       0.041383  0.206167  0.003368  0.011200  0.007450   0.351799
# LotArea           0.043160  0.077672  0.038068  0.001205 -0.014261   0.263843
# OverallQual       0.064886  0.065166 -0.031406  0.070815 -0.027347   0.790982
# OverallCond       0.054811 -0.001985  0.068777 -0.003511  0.043950  -0.077856
# YearBuilt        -0.050364  0.004950 -0.034383  0.012398 -0.013618   0.522897
# YearRemodAdd     -0.038740  0.005829 -0.010286  0.021490  0.035743   0.507101
# MasVnrArea        0.061466  0.011723 -0.029815 -0.005965 -0.008201   0.477493
# BsmtFinSF1        0.062021  0.140491  0.003571 -0.015727  0.014359   0.386420
# BsmtFinSF2        0.088871  0.041709  0.004940 -0.015211  0.031706  -0.011378
# BsmtUnfSF        -0.012579 -0.035092 -0.023837  0.034888 -0.041258   0.214479
# TotalBsmtSF       0.084489  0.126053 -0.018479  0.013196 -0.014969   0.613581
# 1stFlrSF          0.088758  0.131525 -0.021096  0.031372 -0.013604   0.605852
# 2ndFlrSF          0.040606  0.081487  0.016197  0.035164 -0.028700   0.319334
# LowQualFinSF      0.026799  0.062157 -0.003793 -0.022174 -0.028921  -0.025606
# GrLivArea         0.101510  0.170205 -0.002416  0.050240 -0.036526   0.708624
# BsmtFullBath      0.023148  0.067616 -0.023047 -0.025361  0.067049   0.227122
# BsmtHalfBath      0.032121  0.020025 -0.007367  0.032873 -0.046524  -0.016844
# FullBath         -0.008106  0.049604 -0.014290  0.055872 -0.019669   0.560664
# HalfBath          0.072426  0.022381  0.001290 -0.009050 -0.010269   0.284108
# BedroomAbvGr      0.044300  0.070703  0.007767  0.046544 -0.036014   0.168213
# KitchenAbvGr     -0.051613 -0.014525  0.062341  0.026589  0.031687  -0.135907
# TotRmsAbvGrd      0.059383  0.083757  0.024763  0.036907 -0.034516   0.533723
# Fireplaces        0.184530  0.095074  0.001409  0.046357 -0.024096   0.466929
# GarageYrBlt      -0.075418 -0.014501 -0.032417  0.005337 -0.001014   0.486362
# GarageCars        0.050494  0.020934 -0.043080  0.040522 -0.039117   0.640409
# GarageArea        0.051412  0.061047 -0.027400  0.027974 -0.027378   0.623431
# WoodDeckSF       -0.074181  0.073378 -0.009551  0.021011  0.022270   0.324413
# OpenPorchSF       0.074304  0.060762 -0.018584  0.071255 -0.057619   0.315856
# EnclosedPorch    -0.082864  0.054203  0.018361 -0.028887 -0.009916  -0.128578
# 3SsnPorch        -0.031436 -0.007992  0.000354  0.029474  0.018645   0.044584
# ScreenPorch       1.000000  0.051307  0.031946  0.023217  0.010694   0.111447
# PoolArea          0.051307  1.000000  0.029669 -0.033737 -0.059689   0.092404
# MiscVal           0.031946  0.029669  1.000000 -0.006495  0.004906  -0.021190
# MoSold            0.023217 -0.033737 -0.006495  1.000000 -0.145721   0.046432
# YrSold            0.010694 -0.059689  0.004906 -0.145721  1.000000  -0.028923
# SalePrice         0.111447  0.092404 -0.021190  0.046432 -0.028923   1.000000
#
# [38 rows x 38 columns]

# %%
# Skewness
df_train.skew()
# Out:
# Id                0.000000
# MSSubClass        1.407657
# LotFrontage       2.163569
# LotArea          12.207688
# OverallQual       0.216944
# OverallCond       0.693067
# YearBuilt        -0.613461
# YearRemodAdd     -0.503562
# MasVnrArea        2.669084
# BsmtFinSF1        1.685503
# BsmtFinSF2        4.255261
# BsmtUnfSF         0.920268
# TotalBsmtSF       1.524255
# 1stFlrSF          1.376757
# 2ndFlrSF          0.813030
# LowQualFinSF      9.011341
# GrLivArea         1.366560
# BsmtFullBath      0.596067
# BsmtHalfBath      4.103403
# FullBath          0.036562
# HalfBath          0.675897
# BedroomAbvGr      0.211790
# KitchenAbvGr      4.488397
# TotRmsAbvGrd      0.676341
# Fireplaces        0.649565
# GarageYrBlt      -0.649415
# GarageCars       -0.342549
# GarageArea        0.179981
# WoodDeckSF        1.541376
# OpenPorchSF       2.364342
# EnclosedPorch     3.089872
# 3SsnPorch        10.304342
# ScreenPorch       4.122214
# PoolArea         14.828374
# MiscVal          24.476794
# MoSold            0.212053
# YrSold            0.096269
# SalePrice         1.882876
# dtype: float64

# %%
class_counts = df_train['SalePrice'].value_counts()
class_counts
# Out:
# 140000    20
# 135000    17
# 145000    14
# 155000    14
# 190000    13
#           ..
# 84900      1
# 424870     1
# 415298     1
# 62383      1
# 34900      1
# Name: SalePrice, Length: 663, dtype: int64

# %% [markdown]
# ## 1.2 Data Visualisation

# %%
# Histogram
df_train.hist(figsize=(20, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b0502cbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04de2410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04d9ca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04d5f150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04d927d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04d48e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04d09590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04cc0b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04cc0b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04c81350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04beef50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04baf610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04b64c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04b26350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04ada9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04b07bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04ad4710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04a8ad90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04a4b450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b049ffad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b049c2190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04975810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b0492de90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b048f0550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b048a4bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04865290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b0481c910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04851f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04811650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b047c8cd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04781ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04744490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b046f8a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b046aef90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b0466f550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04622ad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b0464fbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b0459b610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b045cfb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b04592150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b045476d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2b044fbc50>]],
#       dtype=object)

# %%
# Scatter plot
fig, ax = plt.subplots()
ax.scatter(df_train['Id'], df_train['SalePrice'])

# %% [markdown]
# ## 1.3 Data preparation

# %%
def preprocess_data(df):
    """
    Performs transformations on df and returns transformed df.
    """
    # Fill the numeric rows with median
    for label, content in df.items():
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                # Add a binary column which tells us if the data was missing or not
                df[label+"_is_missing"] = pd.isnull(content)
                # Fill missing numeric values with median
                df[label] = content.fillna(content.median())
    
        # Filled categorical missing data and turn categories into numbers
        if not pd.api.types.is_numeric_dtype(content):
            df[label+"_is_missing"] = pd.isnull(content)
            # We add +1 to the category code because pandas encodes missing categories as -1
            df[label] = pd.Categorical(content).codes+1
    
    return df

# %%
# Process the test data 
df_train = preprocess_data(df_train)
df_train.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         4         65.0     8450       2      0         4
# 1   2          20         4         80.0     9600       2      0         4
# 2   3          60         4         68.0    11250       2      0         1
# 3   4          70         4         60.0     9550       2      0         1
# 4   5          60         4         84.0    14260       2      0         1
#
#    LandContour  Utilities  ...  GarageYrBlt_is_missing  \
# 0            4          1  ...                   False
# 1            4          1  ...                   False
# 2            4          1  ...                   False
# 3            4          1  ...                   False
# 4            4          1  ...                   False
#
#    GarageFinish_is_missing  GarageQual_is_missing  GarageCond_is_missing  \
# 0                    False                  False                  False
# 1                    False                  False                  False
# 2                    False                  False                  False
# 3                    False                  False                  False
# 4                    False                  False                  False
#
#    PavedDrive_is_missing  PoolQC_is_missing  Fence_is_missing  \
# 0                  False               True              True
# 1                  False               True              True
# 2                  False               True              True
# 3                  False               True              True
# 4                  False               True              True
#
#    MiscFeature_is_missing  SaleType_is_missing  SaleCondition_is_missing
# 0                    True                False                     False
# 1                    True                False                     False
# 2                    True                False                     False
# 3                    True                False                     False
# 4                    True                False                     False
#
# [5 rows x 127 columns]

# %%
# Process the test data 
df_train = preprocess_data(df_train)
df_train.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         4         65.0     8450       2      0         4
# 1   2          20         4         80.0     9600       2      0         4
# 2   3          60         4         68.0    11250       2      0         1
# 3   4          70         4         60.0     9550       2      0         1
# 4   5          60         4         84.0    14260       2      0         1
#
#    LandContour  Utilities  ...  GarageYrBlt_is_missing  \
# 0            4          1  ...                   False
# 1            4          1  ...                   False
# 2            4          1  ...                   False
# 3            4          1  ...                   False
# 4            4          1  ...                   False
#
#    GarageFinish_is_missing  GarageQual_is_missing  GarageCond_is_missing  \
# 0                    False                  False                  False
# 1                    False                  False                  False
# 2                    False                  False                  False
# 3                    False                  False                  False
# 4                    False                  False                  False
#
#    PavedDrive_is_missing  PoolQC_is_missing  Fence_is_missing  \
# 0                  False               True              True
# 1                  False               True              True
# 2                  False               True              True
# 3                  False               True              True
# 4                  False               True              True
#
#    MiscFeature_is_missing  SaleType_is_missing  SaleCondition_is_missing
# 0                    True                False                     False
# 1                    True                False                     False
# 2                    True                False                     False
# 3                    True                False                     False
# 4                    True                False                     False
#
# [5 rows x 127 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 127 entries, Id to SaleCondition_is_missing
# dtypes: bool(46), float64(3), int64(35), int8(43)
# memory usage: 560.5 KB

# %% [markdown]
# ### Modelling

# %% [markdown]
#  ## 2.1 Building an evaluation function

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
from sklearn.linear_model import LinearRegression, Lasso
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error, mean_absolute_error, r2_score

X = df_train.drop('SalePrice', axis=1)
y = df_train['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2)

# Put models in a dictionary
models = {'Logistic Regression': LogisticRegression(),
          'linear_regression' : LinearRegression(),
          'Random Forest': RandomForestRegressor(),
          'linear_model' : linear_model.Lasso(alpha=0.1),
          'XGBoost' : XGBRegressor()
           
          }

# Create a function to fit and score models
def fit_and_score(models, X_train, X_test, y_train, y_test):
    """
    Fits and evaluates given machine learning models.
    models : a dict of differetn Scikit-Learn machine learning models
    X_train : training data (no labels)
    X_test : validation data (no labels)
    y_train : training labels
    y_test : validation labels
    """
    # Set random seed
    np.random.seed(42)
    # Make a dictionary to keep model scores
    model_scores = {}
    # Loop through models
    for name, model in models.items():
        # Fit the model to the data
        model.fit(X_train, y_train)
        # Evaluate the model and append its score to model_scores
        model_scores[name] = model.score(X_test, y_test)
    return model_scores

# %%
model_scores = fit_and_score(models=models,
                             X_train=X_train,
                             X_test= X_test,
                             y_train=y_train,
                             y_test=y_test)

model_scores
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 461088217861.9682, tolerance: 715998331.3579065
#   positive)
# {'Logistic Regression': 0.003424657534246575,
#  'linear_regression': 0.8776956915997516,
#  'Random Forest': 0.8846306185509091,
#  'linear_model': 0.8776752043703093,
#  'XGBoost': 0.8832201121353841}

# %% [markdown]
# ## 2.2 Evaluate Models

# %%
models = {'Logistic Regression': LogisticRegression(),
          'linear_regression' : LinearRegression(),
          'Random Forest': RandomForestRegressor(),
          'linear_model' : linear_model.Lasso(alpha=0.1),
          'XGBoost' : XGBRegressor()
           
          }

# Logistic Regression
model1 = LogisticRegression()
model1.fit(X_train, y_train)
y_preds = model1.predict(X_test)
print('Logistic Regression')
print('MAE', mean_absolute_error(y_test, y_preds))
print('RMSLE', mean_squared_log_error(y_test, y_preds))
print('r-squared', r2_score (y_test, y_preds))

# linear_regression
model2 = LinearRegression()
model2 = LogisticRegression()
model2.fit(X_train, y_train)
y_preds = model2.predict(X_test)
print('linear_regression')
print('MAE', mean_absolute_error(y_test, y_preds))
print('RMSLE', mean_squared_log_error(y_test, y_preds))
print('r-squared', r2_score (y_test, y_preds))

# Random Forest
model3 = RandomForestRegressor()
model3.fit(X_train, y_train)
y_preds = model3.predict(X_test)
print('Random Forest')
print('MAE', mean_absolute_error(y_test, y_preds))
print('RMSLE', mean_squared_log_error(y_test, y_preds))
print('r-squared', r2_score (y_test, y_preds))

# linear_model
model4 = linear_model.Lasso(alpha=0.1)
model4.fit(X_train, y_train)
y_preds = model4.predict(X_test)
print('linear_model')
print('MAE', mean_absolute_error(y_test, y_preds))
print('RMSLE', mean_squared_log_error(y_test, y_preds))
print('r-squared', r2_score (y_test, y_preds))

# XGBoost
model5 = XGBRegressor()
model5.fit(X_train, y_train)
y_preds = model5.predict(X_test)
print('XGBoost')
print('MAE', mean_absolute_error(y_test, y_preds))
print('RMSLE', mean_squared_log_error(y_test, y_preds))
print('r-squared', r2_score (y_test, y_preds))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Logistic Regression
# MAE 42487.41095890411
# RMSLE 0.09326556244478275
# r-squared 0.4068379918680174
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# linear_regression
# MAE 42487.41095890411
# RMSLE 0.09326556244478275
# r-squared 0.4068379918680174
# Random Forest
# MAE 17789.081712328763
# RMSLE 0.020812037575698248
# r-squared 0.8800547644393844
# linear_model
# MAE 19504.547045303807
# RMSLE 0.024925206033025504
# r-squared 0.8776752043703093
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 461088217861.9682, tolerance: 715998331.3579065
#   positive)
# XGBoost
# MAE 17841.52164490582
# RMSLE 0.01842974708519073
# r-squared 0.8832201121353841

# %% [raw]
# ### Choising the model XGBOOST
# score: 0.828759856683738
# RMSLE 0.021842740178599024

# %% [markdown]
# ## Testing our model on a subset (to tune the hyperparameters)

# %%
# %%time

# Instantiate model
model = XGBRegressor()

# Fit the model
model.fit(X_train, y_train)
y_preds = model.predict(X_test)
# Out:
# CPU times: user 1.68 s, sys: 18.7 ms, total: 1.7 s
# Wall time: 433 ms

# %% [markdown]
# ### Hyerparameter tuning with GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
grid = {'n_estimators' : [10, 1000],
        'learning_rate': [0.01, 0.1],
        'gamma' : [0.1, 5],
        'max_depth' : [3, 5, 8], 
        'subsample' : [0.8 ,0.9, 1],
        'colsample_bytree' : [0.3, 0,8],
        'gamma' : [0.1, 5]
        
    
}


xgb_model = GridSearchCV(XGBRegressor(),

                              param_grid=grid,
                              
                              cv=5,
                              verbose=20)

xgb_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8, score=-5.018, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8, score=-4.814, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8, score=-3.513, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8, score=-4.952, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.4s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8, score=-3.743, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9, score=-5.021, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.6s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9, score=-4.810, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9, score=-3.512, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.9s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9, score=-4.949, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9, score=-3.735, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1, score=-5.008, total=   0.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1, score=-4.801, total=   0.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    1.2s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1, score=-3.513, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1, score=-4.948, total=   0.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1, score=-3.743, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    1.4s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8, score=0.853, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    2.3s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8, score=0.563, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    3.2s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8, score=0.902, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    4.1s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8, score=0.914, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    5.0s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8, score=0.906, total=   1.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9, score=0.855, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9, score=0.554, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9, score=0.900, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9, score=0.913, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9, score=0.903, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1, score=0.864, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1, score=0.552, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1, score=0.907, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1, score=0.908, total=   0.8s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=1, score=0.896, total=   0.8s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.8, score=-5.014, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.8, score=-4.806, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.8, score=-3.515, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.8, score=-4.942, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.8, score=-3.742, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.9, score=-5.020, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.9, score=-4.806, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.9, score=-3.512, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.9, score=-4.943, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=0.9, score=-3.737, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=1, score=-5.006, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=1, score=-4.797, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=1, score=-3.514, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=1, score=-4.940, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, subsample=1, score=-3.743, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8, score=0.861, total=   1.4s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8, score=0.613, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8, score=0.900, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8, score=0.923, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8, score=0.907, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.9, score=0.855, total=   1.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.9, score=0.589, total=   1.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.9, score=0.892, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.9, score=0.924, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.9, score=0.906, total=   1.4s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=1, score=0.860, total=   1.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=1, score=0.599, total=   1.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=1, score=0.893, total=   1.4s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=1, score=0.921, total=   1.8s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=1, score=0.901, total=   1.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.8, score=-5.013, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.8, score=-4.806, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.8, score=-3.515, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.8, score=-4.940, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.8, score=-3.742, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.9, score=-5.020, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.9, score=-4.808, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.9, score=-3.512, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.9, score=-4.943, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=0.9, score=-3.738, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=1, score=-5.008, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=1, score=-4.796, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=1, score=-3.514, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=1, score=-4.939, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=10, subsample=1, score=-3.743, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8, score=0.853, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8, score=0.614, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8, score=0.892, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8, score=0.924, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.8, score=0.900, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.9, score=0.849, total=   1.8s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.9, score=0.586, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.9, score=0.886, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.9, score=0.920, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=0.9, score=0.899, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1, score=0.854, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1, score=0.599, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1, score=0.893, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1, score=0.920, total=   1.8s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, n_estimators=1000, subsample=1, score=0.893, total=   2.7s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.8, score=-0.246, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.8, score=-0.077, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.8, score=0.006, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.8, score=-0.075, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.8, score=-0.010, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.9, score=-0.228, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.9, score=-0.073, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.9, score=0.011, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.9, score=-0.082, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.9, score=0.030, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1, score=-0.193, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1, score=-0.049, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1, score=-0.026, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1, score=-0.076, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1, score=0.018, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.8, score=0.852, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.8, score=0.546, total=   1.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.8, score=0.887, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.8, score=0.909, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.8, score=0.898, total=   1.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.9, score=0.870, total=   1.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.9, score=0.532, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.9, score=0.903, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.9, score=0.913, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=0.9, score=0.904, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1, score=0.871, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1, score=0.551, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1, score=0.901, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1, score=0.915, total=   0.8s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1, score=0.900, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8, score=-0.211, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8, score=-0.043, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8, score=0.016, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8, score=-0.029, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8, score=0.012, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9, score=-0.217, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9, score=-0.067, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9, score=0.033, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9, score=-0.057, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9, score=0.021, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1, score=-0.198, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1, score=-0.033, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1, score=0.033, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1, score=-0.029, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1, score=0.008, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8, score=0.845, total=   1.5s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8, score=0.553, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8, score=0.898, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8, score=0.915, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8, score=0.885, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9, score=0.849, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9, score=0.579, total=   1.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9, score=0.893, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9, score=0.918, total=   1.4s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9, score=0.902, total=   1.3s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1, score=0.851, total=   1.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1, score=0.621, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1, score=0.891, total=   1.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1, score=0.914, total=   1.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1, score=0.895, total=   1.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8, score=-0.201, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8, score=-0.049, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8, score=-0.003, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8, score=-0.047, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8, score=0.013, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9, score=-0.218, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9, score=-0.075, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9, score=0.023, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9, score=-0.082, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9, score=0.008, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1, score=-0.209, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1, score=-0.033, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1, score=0.029, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1, score=-0.036, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1, score=0.016, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8, score=0.839, total=   2.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8, score=0.553, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8, score=0.879, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8, score=0.912, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8, score=0.886, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9, score=0.836, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9, score=0.588, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9, score=0.889, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9, score=0.906, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9, score=0.884, total=   2.1s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1, score=0.835, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1, score=0.612, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1, score=0.877, total=   2.0s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1, score=0.904, total=   2.6s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1, score=0.878, total=   1.9s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8, score=-5.018, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8, score=-4.814, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8, score=-3.513, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8, score=-4.952, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.8, score=-3.743, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9, score=-5.021, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9, score=-4.810, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9, score=-3.512, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9, score=-4.949, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.9, score=-3.735, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1, score=-5.008, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1, score=-4.801, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1, score=-3.513, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1, score=-4.948, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1, score=-3.743, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8, score=0.853, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8, score=0.563, total=   0.9s
# [CV] colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=0.3, gamma=5, learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8, score=0.902, total=   0.9s
# ...
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=3, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=10, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=10, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.8, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=0.9, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [CV] colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1
# [CV]  colsample_bytree=8, gamma=5, learning_rate=0.1, max_depth=8, n_estimators=1000, subsample=1, score=nan, total=   0.0s
# [Parallel(n_jobs=1)]: Done 1080 out of 1080 | elapsed:  6.4min finished
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              param_grid={'colsample_bytree': [0.3, 0, 8], 'gamma': [0.1, 5],
#                          'learning_rate': [0.01, 0.1], 'max_depth': [3, 5, 8],
#                          'n_estimators': [10, 1000],
#                          'subsample': [0.8, 0.9, 1]},
#              verbose=20)

# %%
# Find the best model hyperparameters
xgb_model.best_params_
# Out:
# {'colsample_bytree': 0.3,
#  'gamma': 0.1,
#  'learning_rate': 0.01,
#  'max_depth': 5,
#  'n_estimators': 1000,
#  'subsample': 0.8}

# %%
best_model = XGBRegressor(colsample_bytree=0.3,
                          gamma=0.1,
                          learning_rate=0.01,
                          max_depth=5,
                          n_estimators=1000,
                          subsample=0.8)

# %%
# Fit the model
best_model.fit(X_train, y_train)
y_preds = best_model.predict(X_test)

best_model.score(X_test, y_test)
# Out:
# 0.916971086066568

# %%
print('MAE', mean_absolute_error(y_test, y_preds))
print('MSLE', mean_squared_log_error(y_test, y_preds))
print('r-squared', r2_score (y_test, y_preds))
# Out:
# MAE 14741.383508133562
# MSLE 0.013775332911879469
# r-squared 0.916971086066568

# %% [markdown]
# ### Make predictions on test data

# %%
# Import the test data
df_test = pd.read_csv('../input/house-prices-advanced-regression-techniques/test.csv')
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
# Process the test data 
df_test = preprocess_data(df_test)
df_test.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  1461          20         3         80.0    11622       2      0         4
# 1  1462          20         4         81.0    14267       2      0         1
# 2  1463          60         4         74.0    13830       2      0         1
# 3  1464          60         4         78.0     9978       2      0         1
# 4  1465         120         4         43.0     5005       2      0         1
#
#    LandContour  Utilities  ...  GarageCars_is_missing  GarageArea_is_missing  \
# 0            4          1  ...                  False                  False
# 1            4          1  ...                  False                  False
# 2            4          1  ...                  False                  False
# 3            4          1  ...                  False                  False
# 4            2          1  ...                  False                  False
#
#    GarageQual_is_missing  GarageCond_is_missing  PavedDrive_is_missing  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    PoolQC_is_missing  Fence_is_missing  MiscFeature_is_missing  \
# 0               True             False                    True
# 1               True              True                   False
# 2               True             False                    True
# 3               True              True                    True
# 4               True              True                    True
#
#    SaleType_is_missing  SaleCondition_is_missing
# 0                False                     False
# 1                False                     False
# 2                False                     False
# 3                False                     False
# 4                False                     False
#
# [5 rows x 134 columns]

# %%
df_train.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         4         65.0     8450       2      0         4
# 1   2          20         4         80.0     9600       2      0         4
# 2   3          60         4         68.0    11250       2      0         1
# 3   4          70         4         60.0     9550       2      0         1
# 4   5          60         4         84.0    14260       2      0         1
#
#    LandContour  Utilities  ...  GarageYrBlt_is_missing  \
# 0            4          1  ...                   False
# 1            4          1  ...                   False
# 2            4          1  ...                   False
# 3            4          1  ...                   False
# 4            4          1  ...                   False
#
#    GarageFinish_is_missing  GarageQual_is_missing  GarageCond_is_missing  \
# 0                    False                  False                  False
# 1                    False                  False                  False
# 2                    False                  False                  False
# 3                    False                  False                  False
# 4                    False                  False                  False
#
#    PavedDrive_is_missing  PoolQC_is_missing  Fence_is_missing  \
# 0                  False               True              True
# 1                  False               True              True
# 2                  False               True              True
# 3                  False               True              True
# 4                  False               True              True
#
#    MiscFeature_is_missing  SaleType_is_missing  SaleCondition_is_missing
# 0                    True                False                     False
# 1                    True                False                     False
# 2                    True                False                     False
# 3                    True                False                     False
# 4                    True                False                     False
#
# [5 rows x 127 columns]

# %%
set(df_test.columns) - set(X_train.columns)
# Out:
# {'BsmtFinSF1_is_missing',
#  'BsmtFinSF2_is_missing',
#  'BsmtFullBath_is_missing',
#  'BsmtHalfBath_is_missing',
#  'BsmtUnfSF_is_missing',
#  'GarageArea_is_missing',
#  'GarageCars_is_missing',
#  'TotalBsmtSF_is_missing'}

# %%
# Manually adjust df_train to missing columns
df_test = df_test.drop('BsmtFinSF1_is_missing', axis=1)                            
df_test = df_test.drop('BsmtFinSF2_is_missing', axis=1)
df_test = df_test.drop('BsmtFullBath_is_missing', axis=1) 
df_test = df_test.drop('BsmtHalfBath_is_missing', axis=1)
df_test = df_test.drop('BsmtUnfSF_is_missing', axis=1)
df_test = df_test.drop('GarageArea_is_missing', axis=1)
df_test = df_test.drop('GarageCars_is_missing', axis=1)
df_test = df_test.drop('TotalBsmtSF_is_missing', axis=1)
df_test.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  1461          20         3         80.0    11622       2      0         4
# 1  1462          20         4         81.0    14267       2      0         1
# 2  1463          60         4         74.0    13830       2      0         1
# 3  1464          60         4         78.0     9978       2      0         1
# 4  1465         120         4         43.0     5005       2      0         1
#
#    LandContour  Utilities  ...  GarageYrBlt_is_missing  \
# 0            4          1  ...                   False
# 1            4          1  ...                   False
# 2            4          1  ...                   False
# 3            4          1  ...                   False
# 4            2          1  ...                   False
#
#    GarageFinish_is_missing  GarageQual_is_missing  GarageCond_is_missing  \
# 0                    False                  False                  False
# 1                    False                  False                  False
# 2                    False                  False                  False
# 3                    False                  False                  False
# 4                    False                  False                  False
#
#    PavedDrive_is_missing  PoolQC_is_missing  Fence_is_missing  \
# 0                  False               True             False
# 1                  False               True              True
# 2                  False               True             False
# 3                  False               True              True
# 4                  False               True              True
#
#    MiscFeature_is_missing  SaleType_is_missing  SaleCondition_is_missing
# 0                    True                False                     False
# 1                   False                False                     False
# 2                    True                False                     False
# 3                    True                False                     False
# 4                    True                False                     False
#
# [5 rows x 126 columns]

# %%
df_test.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  1461          20         3         80.0    11622       2      0         4
# 1  1462          20         4         81.0    14267       2      0         1
# 2  1463          60         4         74.0    13830       2      0         1
# 3  1464          60         4         78.0     9978       2      0         1
# 4  1465         120         4         43.0     5005       2      0         1
#
#    LandContour  Utilities  ...  GarageYrBlt_is_missing  \
# 0            4          1  ...                   False
# 1            4          1  ...                   False
# 2            4          1  ...                   False
# 3            4          1  ...                   False
# 4            2          1  ...                   False
#
#    GarageFinish_is_missing  GarageQual_is_missing  GarageCond_is_missing  \
# 0                    False                  False                  False
# 1                    False                  False                  False
# 2                    False                  False                  False
# 3                    False                  False                  False
# 4                    False                  False                  False
#
#    PavedDrive_is_missing  PoolQC_is_missing  Fence_is_missing  \
# 0                  False               True             False
# 1                  False               True              True
# 2                  False               True             False
# 3                  False               True              True
# 4                  False               True              True
#
#    MiscFeature_is_missing  SaleType_is_missing  SaleCondition_is_missing
# 0                    True                False                     False
# 1                   False                False                     False
# 2                    True                False                     False
# 3                    True                False                     False
# 4                    True                False                     False
#
# [5 rows x 126 columns]

# %%
# Make predictions on updated test data

model.fit(X_train, y_train)

test_preds = model.predict(df_test)

# %%
test_preds
# Out:
# array([125351.28, 164775.14, 185968.84, ..., 167575.03, 108887.43,
#        226126.84], dtype=float32)

# %% [markdown]
# ## Format predictions asked by Kaggle

# %%
df_preds_test = pd.DataFrame()
df_preds_test['Id'] = df_test['Id']
df_preds_test["SalePrice"] = test_preds
df_preds_test
# Out:
#         Id      SalePrice
# 0     1461  125351.281250
# 1     1462  164775.140625
# 2     1463  185968.843750
# 3     1464  192541.421875
# 4     1465  200590.078125
# ...    ...            ...
# 1454  2915   83916.359375
# 1455  2916   73530.343750
# 1456  2917  167575.031250
# 1457  2918  108887.429688
# 1458  2919  226126.843750
#
# [1459 rows x 2 columns]

# %%
# Export prediction data
df_preds_test.to_csv("./HousePricesAdvanced_XGboost_final.csv", index=False)
